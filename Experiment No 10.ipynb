# %% [markdown]
# # Experiment No. :10

# %% [markdown]
# # Aim:To perform text analysis using NLTK (Tokenization, Frequency Distribution, Stop words and POS Tagging

# %% [markdown]
# Data:23/4/2023

# %% [markdown]
# Roll No: 05

# %% [markdown]
# Section:B

# %% [markdown]
# Year:3rd

# %%
#Text analysis operations with NLTK

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
#In NLTK, PUNKT is an unsupervised trainable model, 
#which means it can be trained on unlabeled data 
#(Data that has not been tagged with information identifying its characteristics, properties, or categories is referred
# -to as unlabeled data.)

# %% [markdown]
# # Tokenization

# %% [markdown]
# Tokenization
# Tokenization is the first step in text analytics. The process of breaking down a text paragraph into smaller chunks such as words or sentence is called Tokenization. Token is a single entity that is building blocks for sentence or paragraph.
# Sentence tokenizer breaks text paragraph into sentences

# %%
from nltk.tokenize import sent_tokenize

# %%
text="""Hello I am Prachi Awandekar.am a Student of PRMCEAM, currently I am in third year.Persuing my BE in Computer Science and Engineering."""

# %%
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Hello I am Prachi Awandekar.am a Student of PRMCEAM, currently I am in third year.Persuing my BE in Computer Science and Engineering.']

# %% [markdown]
# Word tokenizer breaks text paragraph into words

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'I', 'am', 'Prachi', 'Awandekar.am', 'a', 'Student', 'of', 'PRMCEAM', ',', 'currently', 'I', 'am', 'in', 'third', 'year.Persuing', 'my', 'BE', 'in', 'Computer', 'Science', 'and', 'Engineering', '.']

# %% [markdown]
# # Frewquency Distribution

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 21 samples and 24 outcomes>

# %%
fdist.most_common(2)
# Out:
# [('I', 2), ('am', 2)]

# %%
#frequency distribution plot
import matplotlib.pyplot as plt
fdist.plot(30 , cumulative=False)
plt.show()

# %% [markdown]
# # Stopwords

# %% [markdown]
# Stopwords considered as noise in the text. Text may contain stop words such as is, am, are, this, a, an, the, etc.
# In NLTK for removing stopwords, you need to create a list of stopwords and filter out your list of tokens from these words.

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'didn', 'not', 'isn', 'some', 'haven', 'as', "weren't", 'below', 'its', 'up', "shouldn't", 'she', 'yourself', 'who', 'there', 'because', 'yourselves', 'from', 'needn', 'did', "isn't", 'between', 'been', 'being', 'the', 'mightn', 'down', 'of', 'at', 'such', 've', 'y', 'further', "she's", 'their', 'that', "doesn't", 'what', 'should', 'about', 'those', 'him', 'if', 'd', 'shan', 'had', 'won', 'these', 'so', 'his', 'same', 'no', 'me', 'out', 'when', 'nor', "don't", 'a', "aren't", 'hasn', 'where', "hadn't", 'more', "hasn't", 'own', 'our', 'most', 'through', 'themselves', 'my', 'over', 'here', 'can', 'how', 'herself', 'than', 'aren', 'her', 'wouldn', 'which', 'while', "mightn't", "it's", 'm', 'are', 'it', 'having', 'all', 'any', 'mustn', 'am', 'an', "you'd", 'himself', 'each', 'by', "wouldn't", 'he', 'has', 'both', 'in', 'into', 'yours', 'ourselves', 'was', "you're", 'to', 'why', "mustn't", "shan't", 'off', 'ours', "couldn't", "won't", 'you', 'hers', 'itself', 'couldn', 'we', 'doing', 'aft
# ...

# %% [markdown]
# # Removing Stopwords

# %%
filtered_sent=[]
for w in tokenized_word:
 if w not in stop_words:
  filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_word)
print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: ['Hello', 'I', 'am', 'Prachi', 'Awandekar.am', 'a', 'Student', 'of', 'PRMCEAM', ',', 'currently', 'I', 'am', 'in', 'third', 'year.Persuing', 'my', 'BE', 'in', 'Computer', 'Science', 'and', 'Engineering', '.']
# Filterd Sentence: ['Hello', 'I', 'Prachi', 'Awandekar.am', 'Student', 'PRMCEAM', ',', 'currently', 'I', 'third', 'year.Persuing', 'BE', 'Computer', 'Science', 'Engineering', '.']

# %% [markdown]
# # POS Tagging

# %% [markdown]
# The primary target of Part-of-Speech(POS) tagging is to identify the grammatical group of a given word. Whether it is a NOUN, PRONOUN, ADJECTIVE, VERB, ADVERBS, etc. based on the context. POS Tagging looks for relationships
# within the sentence and assigns a corresponding tag to the word.

# %%
import nltk
print (nltk.__version__)
# Out:
# 3.7

# %%
pip install -U nltk
# Out:
# ...
#      ---------------------------------------- 1.5/1.5 MB 406.8 kB/s eta 0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
sent = "Albert Einstein was born in Ulm, Germany in 1879."

# %%
tokens=nltk.word_tokenize(sent)
print(tokens)
# Out:
# ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germany', 'in', '1879', '.']

# %%
nltk.pos_tag(tokens)
# Out:
# [('Albert', 'NNP'),
#  ('Einstein', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Ulm', 'NNP'),
#  (',', ','),
#  ('Germany', 'NNP'),
#  ('in', 'IN'),
#  ('1879', 'CD'),
#  ('.', '.')]
